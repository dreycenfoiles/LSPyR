# %%
from Simulation import *
from Geometry import *
from scipy.optimize import minimize_scalar
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-0198e9421b99> in <module>
# ----> 1 from Simulation import *
#       2 from Geometry import *
#       3 from scipy.optimize import minimize_scalar
#
# f:\foile\Documents\Python Scripts\LSPyR\Simulation.py in <module>
#       4 import matplotlib.pyplot as plt
#       5 import numpy as np
# ----> 6 from ngsolve import *
#       7
#       8 from Geometry import *
#
# ~\Anaconda3\envs\ngsolve\lib\site-packages\ngsolve\__init__.py in <module>
#      10 ngsolve.comp ... function spaces, forms
#      11 """
# ---> 12 import netgen
#      13 from .ngslib import __version__, ngstd, bla, la, fem, comp, solve
#      14
#
# ~\Anaconda3\envs\ngsolve\lib\site-packages\netgen\__init__.py in <module>
#      11 del os
#      12
# ---> 13 from . import libngpy
#      14
#      15 def Redraw(*args, **kwargs):
#
# ...

# %%
radius_list = np.linspace(10,100,10)
mie_theory_peaks = [523, 527, 534, 547, 570, 591, 620, 660, 547, 561]

# %%
peaks = np.array([])
for radius in radius_list:
    mesh = Nanosphere(radius, 0, 300+radius, 600+radius)
    sim = Simulation(mesh)
    sim.RefineMesh()
    res = minimize_scalar(sim.Extinction,bounds=(400,700),method='bounded')
    peaks = np.append(peaks,res.x)
# Out:
# DoF:  74388
# Max Error:  0.6635512273061913
# DoF:  177077
# Max Error:  0.2973205331120331
# DoF:  191262
# Max Error:  0.22988529986657275
# DoF:  215633
# Max Error:  0.15609597556027258
# Wavelength:  514.5898033750316
# Wavelength:  585.4101966249684
# Wavelength:  470.82039324993696
# Wavelength:  517.2607985642645
# Wavelength:  543.2915523106072
# Wavelength:  524.2047921110047
# Wavelength:  524.4653114002074
# Wavelength:  522.2611941127922
# Wavelength:  520.3512129704483
# Wavelength:  521.1477555929188
# Wavelength:  521.2638029587625
# Wavelength:  521.0492976148104
# Wavelength:  520.7826530076884
# Wavelength:  520.9474484378067
# Wavelength:  520.8845021846921
# Wavelength:  520.9789320256273
# Wavelength:  520.9234051085814
# Wavelength:  520.9557463284638
# Wavelength:  520.9382647032453
# Wavelength:  520.9462954140437
# Wavelength:  520.944450722152
# Wavelength:  520.9420878731847
# Wavelength:  520.9406275522126
# Wavelength:  520.942303819571
# ...
